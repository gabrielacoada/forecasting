# %% [markdown]
# # Problem Set #0: Retail Sales for Used Car Dealers
# ## Time Series Analysis
#
# Data: Monthly, Not Seasonally Adjusted
# Period: January 1992 to January 2024
# Source: FRED (Federal Reserve Economic Data)

# %% [markdown]
# ## Setup and Imports

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# For statistical analysis
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import het_breuschpagan
from scipy import stats

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# Out:
# Running cells with 'Python 3.13.11' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3.13 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## 1. Download Data from FRED
#
# We'll download the Retail Sales for Used Car Dealers data from FRED.
#
# **FRED Series ID**: We need to find the correct series ID for "Retail Sales: Used Car Dealers"

# %%
# Option 1: Manual download
# Go to: https://fred.stlouisfed.org/
# Search for "Retail Sales Used Car Dealers"
# Download as CSV and place in this directory

# Option 2: Using pandas_datareader
# First, let's try to get the data using pandas_datareader
try:
    from pandas_datareader import data as pdr
    from pandas_datareader import fred
except ImportError:
    print("pandas_datareader not installed. Installing...")
    # !pip install pandas_datareader
    from pandas_datareader import data as pdr
    from pandas_datareader import fred
# Out:
# Running cells with 'Python 3.13.11' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3.13 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Check data info
df.info()
print(f"\nData range: {df.index.min()} to {df.index.max()}")
print(f"Number of observations: {len(df)}")

# %%
# Rename column for easier reference
df.columns = ['retail_sales']
df.head()

# %% [markdown]
# ## 1a. Extra Credit: Using FRED API

# %%
# To use the FRED API, you need an API key
# Get one free at: https://fred.stlouisfed.org/docs/api/api_key.html

# Uncomment and use this if you have a FRED API key:
# from fredapi import Fred
# fred_api_key = 'YOUR_API_KEY_HERE'
# fred = Fred(api_key=fred_api_key)
# df_api = fred.get_series(series_id, observation_start=start_date, observation_end=end_date)
# df_api = pd.DataFrame(df_api, columns=['retail_sales'])

# %% [markdown]
# ## Save data locally for future use

# %%
# Save the data to CSV
df.to_csv('retail_sales_used_cars.csv')
print("Data saved to 'retail_sales_used_cars.csv'")

# %% [markdown]
# ## Next Steps
#
# Now that we have the data, we can proceed with:
# - (b) Graphing and analyzing the data
# - (c) Finding the best trend model
# - (d) Testing for structural breaks
# - And so on...
